# %%
# %matplotlib inline
from matplotlib.pyplot import *

import numpy as np
import scipy as sp
import pandas as pd
from datetime import datetime

# %%
x = np.arange(0, 31, 1)

y = 1.08 ** x

y2 = (1.08 - 0.0075) ** x

y3 = (1.08 - 0.02) ** x

plot(x, y)
plot(x, y2)
plot(x, y3)

# %%
y
# Out:
# array([ 1.        ,  1.08      ,  1.1664    ,  1.259712  ,  1.36048896,
#         1.46932808,  1.58687432,  1.71382427,  1.85093021,  1.99900463,
#         2.158925  ,  2.331639  ,  2.51817012,  2.71962373,  2.93719362,
#         3.17216911,  3.42594264,  3.70001805,  3.9960195 ,  4.31570106,
#         4.66095714,  5.03383372,  5.43654041,  5.87146365,  6.34118074,
#         6.8484752 ,  7.39635321,  7.98806147,  8.62710639,  9.3172749 ,
#        10.06265689])
